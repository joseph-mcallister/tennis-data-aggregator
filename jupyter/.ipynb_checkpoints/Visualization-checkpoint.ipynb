# %%
import pandas
import plotly
import plotly.express as px

# %%
players = pandas.read_csv('../data/Players.csv')
utr = pandas.read_csv('../data/UTREntries.csv')

# %%
merged = players.merge(utr, how='left', on='utrProfileId')
merged = merged.drop_duplicates(subset='utrProfileId', keep="first")

# %%
merged
# Out:
#       id_x                    name  utrProfileId  itfProfileId gradClassName  \
# 0        1            Lev Levyatov       1860384           NaN           NaN
# 3        2  Juan Ignacio Lombisano       1016727           NaN           NaN
# 7        3           Jakub Svoboda        116884           NaN     Sophomore
# 11       4           Amadei Hutsul        847444           NaN           NaN
# 14       5          Florian Ledoux       1239433           NaN           NaN
# ...    ...                     ...           ...           ...           ...
# 3693  3604        Lorenzo Claverie       2088735           NaN           NaN
# 3694  3606             Luke Casper       2097290           NaN           NaN
# 3695  3697            James Mccabe       1743600           NaN           NaN
# 3696  3699   Alexander Hoogmartens        275541           NaN           NaN
# 3697  3703            Xiaofei Wang        261296           NaN           NaN
#
# ...

# %%
px.choropleth(data_frame=merged, lat="latitude",lon="longitude")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-65e13e66bee3> in <module>
# ----> 1 px.choropleth(data_frame=merged, lat="latitude",lon="longitude")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/plotly/express/_chart_types.py in choropleth(data_frame, lat, lon, locations, locationmode, geojson, featureidkey, color, hover_name, hover_data, custom_data, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, projection, scope, center, title, template, width, height)
#     965     colored region mark on a map.
#     966     """
# --> 967     return make_figure(
#     968         args=locals(),
#     969         constructor=go.Choropleth,
#
# ...

# %%
fig = px.scatter_geo(merged, 
                     lat="latitude", 
                     lon="longitude",
                     opacity=0.3,
                     title="High Likelihood D1 Tennis Players"
                     )
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-3b073f4b838c> in <module>
# ----> 1 fig = px.scatter_geo(merged,
#       2                      lat="latitude",
#       3                      lon="longitude",
#       4                      opacity=0.3,
#       5                      color="red",
#
# ~/opt/anaconda3/lib/python3.8/site-packages/plotly/express/_chart_types.py in scatter_geo(data_frame, lat, lon, locations, locationmode, color, text, hover_name, hover_data, custom_data, size, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, opacity, size_max, projection, scope, center, title, template, width, height)
#    1016     by a symbol mark on a map.
#    1017     """
# -> 1018     return make_figure(
#    1019         args=locals(),
# ...
